# %%
import pickle
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib.patches as pat
from sklearn.preprocessing import RobustScaler
from scipy import signal
# %matplotlib inline
from scipy.stats import skew,kurtosis
import numpy as np
from scipy import signal
from scipy.stats import iqr
import pickle
path = '/home/mullah/Downloads/mperf'
destination_dir = './data_images/'
participants = os.listdir(path)
left_right = ['left_final_data_decoded.csv', 'right_final_data_decoded.csv']
clf = pickle.load(open('./temp/classifier.p','rb'))
final_data = []
label_col = []
for participant in participants:
    file_list = os.listdir(path+'/'+participant)
    for file in file_list:
        final_path = path+'/'+participant+'/'+file+'/'
        files = os.listdir(final_path)
        for r in range(2):
            try:
                ppg_data = pd.read_csv(final_path+left_right[r],compression='gzip',sep=',',header=None).values
                final_data.append([ppg_data,final_path,r])
            except Exception as e:
                print(e)
                continue
# Out:
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/879233b3-262c-4b19-a344-f4d595d08d26/20180115/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/879233b3-262c-4b19-a344-f4d595d08d26/20180115/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/879233b3-262c-4b19-a344-f4d595d08d26/20180119/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180121/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180121/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180130/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180130/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180117/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180117/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180115/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180115/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180122/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180122/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180201/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180201/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180113/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/f29a8628-ed1d-445a-9316-b4eb62fed4d7/20180113/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/17b79ee0-4d3c-44ac-bfea-90b1f0540d4b/20180120/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/17b79ee0-4d3c-44ac-bfea-90b1f0540d4b/20180106/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/17b79ee0-4d3c-44ac-bfea-90b1f0540d4b/20180106/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/17b79ee0-4d3c-44ac-bfea-90b1f0540d4b/20180111/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/17b79ee0-4d3c-44ac-bfea-90b1f0540d4b/20180107/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/24809752-2bcd-424f-aac1-5d909026b0c4/20180209/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/36f6e239-816a-4508-9126-3b612741c26d/20180212/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/36f6e239-816a-4508-9126-3b612741c26d/20180212/right_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/36f6e239-816a-4508-9126-3b612741c26d/20180211/left_final_data_decoded.csv'
# [Errno 2] No such file or directory: '/home/mullah/Downloads/mperf/36f6e239-816a-4508-9126-3b612741c26d/20180211/right_final_data_decoded.csv'

# %%
import math
def complementary_filter(accel_gyro, fq=25):
    ts = accel_gyro[:,0]
    acc_x = accel_gyro[:,5]
    acc_y = accel_gyro[:,6]
    acc_z = accel_gyro[:,7]
    gyr_x = accel_gyro[:,8]
    gyr_y = accel_gyro[:,9]
    gyr_z = accel_gyro[:,10]

    dt = 1.0 / fq  # 1/16.0;
    M_PI = math.pi
    hpf = 0.85
    lpf = 0.15

    thetaX_acc = [0] * len(acc_x)  # math.atan2(-acc_z,acc_y)*180/M_PI;
    thetaY_acc = [0] * len(acc_x)  # math.atan2(acc_x,acc_z)*180/M_PI;
    thetaZ_acc = [0] * len(acc_x)  # math.atan2(acc_y,acc_x)*180/M_PI;

    thetaX = [0] * len(gyr_x)
    thetaY = [0] * len(gyr_y)
    thetaZ = [0] * len(gyr_z)

    for index in range(len(gyr_x)):
        thetaX_acc[index] = math.atan2(-acc_z[index], acc_y[index]) * 180 / M_PI
        thetaY_acc[index] = math.atan2(acc_x[index], acc_z[index]) * 180 / M_PI
        thetaZ_acc[index] = math.atan2(acc_y[index], acc_x[index]) * 180 / M_PI

        if index == 0:
            thetaX[index] = hpf * thetaX[index] * dt + lpf * thetaX_acc[index]
            thetaY[index] = hpf * thetaY[index] * dt + lpf * thetaY_acc[index]
            thetaZ[index] = hpf * thetaZ[index] * dt + lpf * thetaZ_acc[index]
        else:
            thetaX[index] = hpf * (thetaX[index - 1] + gyr_x[index] * dt) + lpf * thetaX_acc[index]
            thetaY[index] = hpf * (thetaY[index - 1] + gyr_y[index] * dt) + lpf * thetaY_acc[index]
            thetaZ[index] = hpf * (thetaZ[index - 1] + gyr_z[index] * dt) + lpf * thetaZ_acc[index]

    roll_pitch_yaw = np.zeros((len(ts),7))
    roll_pitch_yaw[:,0] = ts
    roll_pitch_yaw[:,1:4] =  accel_gyro[:,1:4]
    roll_pitch_yaw[:,4] = thetaX
    roll_pitch_yaw[:,5] = thetaY
    roll_pitch_yaw[:,6] = thetaZ
    return roll_pitch_yaw

def get_metric(window):
    f,pxx = signal.welch(window[:,1],fs=25,nperseg=len(window[:,1]),nfft=1000)
    pxx = np.abs(pxx)
    pxx = pxx/max(pxx)
    return np.array([skew(window[:,1]),kurtosis(window[:,1]),np.trapz(pxx[np.where((f>=.8)&(f<=2.5))[0]])/np.trapz(pxx),
                len(np.where(np.diff(np.signbit(window[:,1])))[0])/len(window[:,1])]).reshape(-1,4)

def get_classified_data(ppg_data,final_path,r,clf):
    print(ppg_data.shape)
    roll_pitch_yaw = complementary_filter(ppg_data)
    print(roll_pitch_yaw.shape)
    final_ppg_data = np.zeros((ppg_data.shape[0],20))
    final_ppg_data[:,14:17] = roll_pitch_yaw[:,4:]
    print(roll_pitch_yaw.shape,'again')
    for i,t in enumerate(ppg_data[:,0]):
        index = np.where((ppg_data[:,0]>=t-2.5*500)&(ppg_data[:,0]<t+2.5*500))[0]
        if len(index) < .66*25*2.5:
            final_ppg_data[i,:] = [0]*20
            continue
        final_ppg_data[i,:11] = ppg_data[i,:]
        ppg_window = ppg_data[index,:]
        temp_window = RobustScaler().fit_transform(ppg_window[:,2:5])
        final_ppg_data[i,17:] = temp_window[ppg_window[:,0]==t,:]
        for k in range(2,5,1):
            window = np.concatenate([ppg_window[:,0].reshape(-1,1),signal.detrend(temp_window[:,k-2]).reshape(-1,1)],
                                    axis=1)
            f = get_metric(window)
            final_ppg_data[i,11+k-2] = clf.predict_proba(f)[0,1]
        if i%1000==0:
            print(i,final_path,r)
    final_ppg_data = final_ppg_data[final_ppg_data[:,0]>0,:]
    print(final_ppg_data.shape,'final')
    return final_ppg_data,final_path,r

# %%
final_data = pickle.load(open('./data_saved/data_all_mperf.p','rb'))

# %%
import numpy as np
final_data1 = []
for a in final_data:
    if len(a[0])<10000:
        continue
    a[0][:,5:8] = a[0][:,5:8]*2/16384
    a[0][:,8:] = 500.0 * a[0][:,8:] / 32768
    split_data = np.array_split(a[0],10)
    for b in split_data:
        final_data1.append([b,a[1],a[2]])
print(len(final_data))
final_data = final_data1
print(len(final_data1))
# Out:
# 197
# 1960

# %%
clf = pickle.load(open('./temp/classifier.p','rb'))
from joblib import Parallel,delayed
final_data2 = Parallel(n_jobs=20,verbose=2)(delayed(get_classified_data)(a[0],a[1],a[2],clf) for a in final_data)
pickle.dump(final_data2,open('./data_saved/data_all_mperf_processed.p','wb'))
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done   1 tasks      | elapsed: 56.6min
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed: 361.3min
# [Parallel(n_jobs=20)]: Done 325 tasks      | elapsed: 548.3min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed: 691.6min
# [Parallel(n_jobs=20)]: Done 973 tasks      | elapsed: 1136.7min
# [Parallel(n_jobs=20)]: Done 1418 tasks      | elapsed: 1922.2min
# [Parallel(n_jobs=20)]: Done 1960 out of 1960 | elapsed: 2764.5min finished

# %%
import pickle
import numpy as np
final_data = pickle.load(open('./data_saved/data_all_mperf_processed.p','rb'))

# %%
import matplotlib.pyplot as plt
plt.plot(final_data[0][0][7000:8000,14:17])
plt.show()
plt.plot(final_data[0][0][7000:8000,17:])
plt.show()
plt.plot(final_data[0][0][7000:8000,11:14])
plt.show()

# %%
# pickle.dump([window_col,label_col],open('./data_saved/windows_all_inertail.p','wb'))

# %%
pickle.dump(final_data,open('./data_saved/data_all_mperf.p','wb'))

# %%
label_col = np.array([np.array(a) for a in label_col])

# %%
x = [np.var(np.sum(np.abs(a[:,5:8]),axis=1)) for a in window_col]

# %%
feature = np.zeros((label_col.shape[0],2))

# %%
feature[:,1] = x
feature[:,0] = label_col[:,-1]

# %%
plt.scatter(x,np.max(label_col,axis=1))
plt.show()

# %%
import pandas as pd
import seaborn as sns
df = pd.DataFrame(feature,columns=['x','y'])
sns.jointplot(x='x', y='y', kind="kde", color="k",data=df)
plt.ylim([0,.25])

# %%
len(x)
